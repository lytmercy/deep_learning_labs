# %% [markdown]
# # Laboratory work #3

# %% [markdown]
# ## Downloading Dataset
# My dataset is Airbus Ship Detection Challenge (from [kaggle](https://www.kaggle.com/competitions/airbus-ship-detection))

# %%
import tensorflow as tf
from keras.utils import Sequence
from keras import layers
from keras.layers import Input, Activation, BatchNormalization
from keras.layers import RandomFlip, RandomRotation, RandomHeight, RandomWidth, RandomZoom
from keras.layers import Conv2D, SeparableConv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D
from keras.losses import Loss
from keras.metrics import Metric
from keras.optimizers import Adam
from keras.models import Model, Sequential, load_model
from keras.callbacks import ModelCheckpoint
from keras import backend as K_back


# Import other libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import itertools
import time
from pathlib import Path
import random
import os

# %% [markdown]
# ## Prepare help functions

# %% [markdown]
# ### Segmentation

# %%
def rle_decode(rle_string, shape=(768, 768)):
    """
    Function for decoding run-length encoding mask from string;
    :param rle_string: run-length string from csv file;
    :param shape: shape of output image;
    :return: tensor as image mask.
    """
    # Split and convert string to tensor of number from string
    rle_code = rle_string.split()
    # Split start and lengths data from rle string
    starts, lengths = [np.asarray(x, dtype=int) for x in (rle_code[0:][::2], rle_code[1:][::2])]
    starts -= 1

    # Make ones to be scattered
    ends = starts + lengths
    mask_flat = np.zeros(shape[0] * shape[1], dtype=np.uint8)

    for lo, hi in zip(starts, ends):
        mask_flat[lo:hi] = 1

    # Reshape into image mask
    mask =  np.reshape(mask_flat, shape)

    return mask.astype(np.float32)

# %%
def load_prepare_image(image_path, image_size=(256, 256)):
    """
    Loading and processing image from directory;
    :param image_path: path to image;
    :param image_size: size of image for processing;
    :return: processed image.
    """
    # Read image file from directory
    image_array = tf.io.read_file(image_path)
    # Define image size in tensor format
    tensor_size = tf.constant(image_size)
    # Decode image file to colour image tensor
    decoded_image = tf.image.decode_jpeg(image_array, channels=3)  # channels -- colour channels
    # Convert uint8 tensor to floats in the [0, 1] range
    decoded_image = tf.image.convert_image_dtype(decoded_image, dtype=tf.float32)
    # Resize the image into tensor_size of determine size
    decoded_image = tf.image.resize(decoded_image, size=tensor_size)

    return decoded_image

# %%
def train_valid_ids_split(list_ids, train_split=0.8):
    """
    Splitting list ids to train and validation list with ids;
    :param list_ids: list with train list_ids;
    :param train_split: float per cent value of training split size;
    :return: two list of train and validation ids.
    """
    # Define size of list with ids
    list_size = np.size(list_ids)
    # Define train size of list with ids
    train_size = int(train_split * list_size)
    # Set train & validation list with ids
    train_list_ids = list_ids[:train_size]
    valid_list_ids = list_ids[train_size:]

    return train_list_ids, valid_list_ids

# %%
class ASDGenerator(Sequence):
    """Class generates data for Keras model (Segmentation task)"""

    def __init__(self, list_ids, gt_df, mode="fit", base_path="../input/dataset/train", batch_size=32,
                 image_size=(256, 256), color_channels=3, random_state=17, shuffle=True):
        """
        :param list_ids: list with ids that data will be generated for;
        :param gt_df: ground truth pandas.DataFrame(), with data that will be generated for ids from list_ids;
        :param mode: string var that indicate data generated mode;
        :param base_path: string with the path where the images are stored;
        :param batch_size: number of the batch size;
        :param image_size: the shape of the image that will be processed in the model;
        :param color_channels: number of color channels;
        :param random_state: random state for shuffle image ids from list_ids;
        :param shuffle: bool that indicates, shuffling image ids or not;
        """
        self.image_size = image_size
        self.batch_size = batch_size
        self.gt_df = gt_df
        self.mode = mode
        self.base_path = base_path
        self.list_ids = list_ids
        self.color_channels = color_channels
        self.shuffle = shuffle
        self.random_state = random_state

        # Init indexes array for store all indexes
        self.indexes = np.array([])
        # Run on_epoch_end method for shuffle and init "indexes" attribute
        self.on_epoch_end()
        # First set random seed
        np.random.seed(self.random_state)

    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        self.indexes = np.arange(len(self.list_ids))
        if self.shuffle is True:
            np.random.seed(self.random_state)
            np.random.shuffle(self.indexes)

    def __len__(self):
        """Denotes the number of batches per epoch"""
        return int(np.floor(len(self.list_ids) / self.batch_size))

    def __getitem__(self, index):
        """Generate one batch of data"""
        # Generate indexes of the batch
        indexes = self.indexes[index * self.batch_size:(index+1) * self.batch_size]
        # Find list of IDs
        list_ids_batch = [self.list_ids[k] for k in indexes]
        # Generate X variable that contains images
        X = self.__generate_x(list_ids_batch)
        # Check string attribute mode for 'fit' mode
        if self.mode == "fit":
            # Generate y variable that contains masks for images
            y = self.__generate_y(list_ids_batch)
            # And return batch X and y variable
            return X, y
        # Check string attribute mode for 'predict' mode
        elif self.mode == "predict":
            # Return only one variable X (images)
            return X
        else:
            # When mode is no 'fit' or 'predict' then rise Attribute Error
            raise AttributeError("The mode parameter must be set to 'fit' or 'predict'.")

    def __generate_x(self, list_ids_batch):
        """Generates data (images) in the current batch sample"""
        # Initialization X as an empty numpy.array with determined shape
        X = np.empty((self.batch_size, *self.image_size, self.color_channels))
        # Generate data from gt_df with ids from list_ids_batch
        for i, image_id in enumerate(list_ids_batch):
            image_path = self.base_path / image_id
            image = load_prepare_image(str(image_path), self.image_size)
            # Store sample image in numpy.array
            X[i, ] = image

        return X

    def __generate_y(self, list_ids_batch):
        """Generates masks for the image in the current batch sample"""
        # Initialization y as an empty numpy array with determined shape
        y = np.empty((self.batch_size, *self.image_size, 1))
        # Generate masks from gt_df with ids from list_ids_batch
        for i, image_id in enumerate(list_ids_batch):
            # Get masks for concrete image
            masks_df = self.gt_df[self.gt_df["ImageId"] == image_id]
            # Get coded rle string from dataframe of masks for concrete image
            coded_rle_strings = masks_df["EncodedPixels"].values
            # Set tensor with zeros value for all masks
            # (768, 768) - this shape of ground truth masks
            all_masks = tf.zeros((768, 768), dtype=tf.float32)
            # Iter through rle strings of all masks for concrete image
            if coded_rle_strings[0] is not np.nan:
                for mask in coded_rle_strings:
                    # Add mask to only one tensor for all masks
                    all_masks += tf.transpose(rle_decode(mask))

            # Resize masks to image_size for model
            all_masks = tf.image.resize(tf.expand_dims(all_masks, -1), size=self.image_size)
            # Store sample mask in y (numpy.array)
            y[i, ] = all_masks

        return y

# %%
def plot_history_curves(history):
    """
    Returns separate loss curves for training and validation metrics.
    :param history: history from process of training model.
    :return: plotted separate curves for training and validation.
    """
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    dice_score = history.history['dice_score']
    val_dice_score = history.history['val_dice_score']

    epochs = range(len(history.history['loss']))

    # Plotting loss
    plt.plot(epochs, loss, label='training_loss')
    plt.plot(epochs, val_loss, label='val_loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.legend()
    plt.show()

    # Plotting dice_score
    plt.figure()
    plt.plot(epochs, dice_score, label='training_dice_score')
    plt.plot(epochs, val_dice_score, label='val_dice_score')
    plt.title('Dice Score')
    plt.xlabel('Epochs')
    plt.legend()
    plt.show()

# %%
class DiceLoss(Loss):
    """Class for creating the loss function is named dice loss in compiling the model."""
    def __init__(self, name='dice_loss', gama=2):
        """
        Initialize attribute for class;
        :param name: name of this loss function;
        :param gama: some constant for squaring y_true and y_pred
        """
        super(DiceLoss, self).__init__(name=name)
        self.gama = gama

    def call(self, y_true, y_pred):
        """Compute dice loss"""
        y_true, y_pred = tf.cast(y_true, dtype=tf.float32), tf.cast(y_pred, dtype=tf.float32)

        nominator = 2 * tf.reduce_sum(tf.abs(tf.multiply(y_pred, y_true)))
        denominator = tf.reduce_sum(y_pred ** self.gama) + tf.reduce_sum(y_true ** self.gama)

        return 1 - tf.math.divide_no_nan(nominator, denominator)

# %%
class DiceScore(Metric):
    """Class for use metric dice score (f1-score) in model compile metrics."""
    def __init__(self,
                 name='dice_score',
                 dtype='float32',
                 num_classes=2,
                 **kwargs):
        """
        Initialize attribute for class;
        :param name: refers to the name of the metric;
        :param dtype: it's data type for this metric;
        """
        super(DiceScore, self).__init__(name=name, dtype=dtype, **kwargs)
        # Setting begin confusion matrix
        self.total_cm = self.add_weight(
                "total_confusion_matrix",
                shape=(num_classes, num_classes),
                initializer="zeros"
        )
        self.num_classes = num_classes

    def update_state(self, y_true, y_pred, sample_weight=None):
        """Accumulate the prediction to current confusion matrix."""
        y_true = tf.cast(y_true, self._dtype)
        y_pred = tf.cast(y_pred, self._dtype)

        # Flatten the input if its rank > 1.
        if y_pred.shape.ndims > 1:
            y_pred = tf.reshape(y_pred, [-1])
        if y_true.shape.ndims > 1:
            y_true = tf.reshape(y_true, [-1])

        # Accumulate the prediction to current confusion matrix.
        current_cm = tf.math.confusion_matrix(
                y_true,
                y_pred,
                self.num_classes,
                weights=sample_weight,
                dtype=self._dtype
        )

        return self.total_cm.assign_add(current_cm)

    def result(self):
        """Compute the Dice score via the confusion matrix."""
        sum_over_row = tf.cast(
                tf.reduce_sum(self.total_cm, axis=0), dtype=self._dtype
        )
        sum_over_col = tf.cast(
                tf.reduce_sum(self.total_cm, axis=1), dtype=self._dtype
        )

        true_positives = tf.cast(
                tf.linalg.tensor_diag_part(self.total_cm), dtype=self._dtype
        )

        # sum_over_row + sum_over_col =
        #       2 * true_positives + false_positives + false_negatives
        denominator = sum_over_row + sum_over_col

        # If the denominator is 0, we need to ignore the class.
        num_valid_entries = tf.reduce_sum(
                tf.cast(tf.not_equal(denominator, 0), dtype=self._dtype)
        )

        return tf.math.divide_no_nan(2 * true_positives, denominator)

    def reset_state(self):
        """Override reset_state method from Metric"""
        K_back.set_value(
                self.total_cm, np.zeros((self.num_classes, self.num_classes))
        )

# %%
def get_model(image_size, num_classes, entry_filters, entry_kernel_size, entry_activation):
    """
    Function for construct the model;
    :param image_size: size of the images which will be used model when getting data;
    :param num_classes: that number of classes that model will be predicted on the image;
    :param entry_filters: the number of filters which will be defined in the entry block of the model;
    :param entry_kernel_size: the size of the kernel will be defined in the entry block of the model;
    :param entry_activation: the name of the activation function which will be used in the entry block of the model;
    :return: built Keras model.
    """
    # Create data augmentation layer
    data_augmentation = Sequential([
        RandomFlip('horizontal'),  # randomly flip images on horizontal edge
        RandomRotation(0.1),  # randomly rotate images by a specific amount
        RandomHeight(0.003),  # randomly adjust the height of an image by a specific amount
        RandomWidth(0.003),  # randomly adjust the width of an image by a specific amount
        RandomZoom(0.1),  # randomly zoom into an image
    ])

    # Initialize Input layer
    inputs = Input(shape=image_size + (3,))
    # Initialize Data augmentation layer
    # x = data_augmentation(inputs)  # augment images (only happens during training)

    # ## [First half of the network: down-sampling inputs] ## #

    # Entry block
    x = Conv2D(entry_filters, entry_kernel_size, strides=2, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation(entry_activation)(x)

    previous_block_activation = x  # Set aside residual

    # Blocks 1, 2, 3 are identical apart from the feature depth.
    for filters in [64, 128, 256]:
        x = Activation('relu')(x)
        x = SeparableConv2D(filters, 3, padding='same')(x)
        x = BatchNormalization()(x)

        x = Activation('relu')(x)
        x = SeparableConv2D(filters, 3, padding='same')(x)
        x = BatchNormalization()(x)

        x = MaxPooling2D(3, strides=2, padding='same')(x)

        # Project residual
        residual = Conv2D(filters, 1, strides=2, padding='same')(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    # ## [Second half of the network: up-sampling inputs] ## #

    for filters in [256, 128, 64, entry_filters]:
        x = Activation('relu')(x)
        x = Conv2DTranspose(filters, 3, padding='same')(x)
        x = BatchNormalization()(x)

        x = Activation('relu')(x)
        x = Conv2DTranspose(filters, 3, padding='same')(x)
        x = BatchNormalization()(x)

        x = UpSampling2D(2)(x)

        # Project residual
        residual = UpSampling2D(2)(previous_block_activation)
        residual = Conv2D(filters, 1, padding='same')(residual)
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    # Add a per-pixel classification layer
    outputs = Conv2D(num_classes, 3, activation='sigmoid', padding='same')(x)

    # Define the model
    model = Model(inputs, outputs)

    return model

# %% [markdown]
# ## Segmentation

# %% [markdown]
# ### Preprocess Data

# %%
# Add base path of dataset
base_path = Path("../input/asd_dataset")

# %%
# View how many images we have
num_train_images = len(os.listdir(base_path / "train"))
num_test_images = len(os.listdir(base_path / "test"))
print(f"Number of images for training: {num_train_images}")
print(f"Number of images for testing: {num_test_images}")
# Out:
# Number of images for training: 8760
# Number of images for testing: 8318

# %%
def view_random_image(target_dir, target_type):
    """Plotting one random image from dataset"""
    # Setup target directory
    target_folder = target_dir / target_type
    # Get a random image path
    random_image = random.sample(os.listdir(target_folder), 1)
    # Read the image and plot it
    img = tf.io.read_file(str(target_folder / random_image[0]))
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    plt.imshow(img)
    plt.title(random_image)
    plt.axis("off")

    # Show the shape of the image
    print(f"Image shape: {img.shape}")
    return img

# %%
# View a random image from the training dataset
image = view_random_image(base_path, "train")
# Out:
# Image shape: (768, 768, 3)

# %%
# View the tensor of image
image
# Out:
# <tf.Tensor: shape=(768, 768, 3), dtype=float32, numpy=
# array([[[0.23529413, 0.34509805, 0.34901962],
#         [0.22352943, 0.33333334, 0.3372549 ],
#         [0.21568629, 0.3254902 , 0.3372549 ],
#         ...,
#         [0.227451  , 0.34901962, 0.36862746],
#         [0.23529413, 0.35686275, 0.37647063],
#         [0.24313727, 0.3647059 , 0.38431376]],
#
#        [[0.26666668, 0.37647063, 0.3803922 ],
#         [0.24313727, 0.3529412 , 0.35686275],
#         [0.21960786, 0.32941177, 0.34117648],
#         ...,
#         [0.21960786, 0.34117648, 0.36078432],
#         [0.21960786, 0.34117648, 0.36078432],
#         [0.22352943, 0.34509805, 0.3647059 ]],
#
#        [[0.2627451 , 0.3803922 , 0.3803922 ],
#         [0.2392157 , 0.35686275, 0.35686275],
#         [0.21568629, 0.33333334, 0.34117648],
#         ...,
#         [0.21176472, 0.33333334, 0.3529412 ],
#         [0.20784315, 0.32941177, 0.34901962],
#         [0.21176472, 0.33333334, 0.3529412 ]],
#
#        ...,
#
# ...

# %%
# View the image shape
image.shape
# Out:
# TensorShape([768, 768, 3])

# %%
# Check the *.csv files to use that later
# load train_ship_segmentations_v2.csv to pandas.DataFrame()
ground_truth_df = pd.read_csv(base_path / "train_ship_segmentations_v2.csv")
ground_truth_df.head()
# Out:
#          ImageId                                      EncodedPixels
# 0  00003e153.jpg                                                NaN
# 1  0001124c7.jpg                                                NaN
# 2  000155de5.jpg  264661 17 265429 33 266197 33 266965 33 267733...
# 3  000194a2d.jpg  360486 1 361252 4 362019 5 362785 8 363552 10 ...
# 4  000194a2d.jpg  51834 9 52602 9 53370 9 54138 9 54906 9 55674 ...

# %%
# View number of masks for segmentations
num_masks = ground_truth_df.shape[0]
num_masks
# Out:
# 231723

# %%
# Check ImageId of image with index 2
ground_truth_df.ImageId[2]
# Out:
# '000155de5.jpg'

# %%
# Check EncodedPixels (masks) of image with index 2
ground_truth_df.EncodedPixels[2]
# Out:
# '264661 17 265429 33 266197 33 266965 33 267733 33 268501 33 269269 33 270037 33 270805 33 271573 33 272341 33 273109 33 273877 33 274645 33 275413 33 276181 33 276949 33 277716 34 278484 34 279252 33 280020 33 280788 33 281556 33 282324 33 283092 33 283860 33 284628 33 285396 33 286164 33 286932 33 287700 33 288468 33 289236 33 290004 33 290772 33 291540 33 292308 33 293076 33 293844 33 294612 33 295380 33 296148 33 296916 33 297684 33 298452 33 299220 33 299988 33 300756 33 301524 33 302292 33 303060 33 303827 34 304595 34 305363 33 306131 33 306899 33 307667 33 308435 33 309203 33 309971 33 310739 33 311507 33 312275 33 313043 33 313811 33 314579 33 315347 33 316115 33 316883 33 317651 33 318419 33 319187 33 319955 33 320723 33 321491 33 322259 33 323027 33 323795 33 324563 33 325331 33 326099 33 326867 33 327635 33 328403 33 329171 33 329938 34 330706 34 331474 33 332242 33 333010 33 333778 33 334546 33 335314 33 336082 33 336850 33 337618 33 338386 33 339154 33 339922 33 340690 
# ...

# %%
# View mask tensor of image with index 2
rle_tensor = tf.strings.to_number(tf.strings.split(ground_truth_df.EncodedPixels[2]), tf.int64)
rle_tensor
# Out:
# <tf.Tensor: shape=(208,), dtype=int64, numpy=
# array([264661,     17, 265429,     33, 266197,     33, 266965,     33,
#        267733,     33, 268501,     33, 269269,     33, 270037,     33,
#        270805,     33, 271573,     33, 272341,     33, 273109,     33,
#        273877,     33, 274645,     33, 275413,     33, 276181,     33,
#        276949,     33, 277716,     34, 278484,     34, 279252,     33,
#        280020,     33, 280788,     33, 281556,     33, 282324,     33,
#        283092,     33, 283860,     33, 284628,     33, 285396,     33,
#        286164,     33, 286932,     33, 287700,     33, 288468,     33,
#        289236,     33, 290004,     33, 290772,     33, 291540,     33,
#        292308,     33, 293076,     33, 293844,     33, 294612,     33,
#        295380,     33, 296148,     33, 296916,     33, 297684,     33,
#        298452,     33, 299220,     33, 299988,     33, 300756,     33,
#        301524,     33, 302292,     33, 303060,     33, 303827,     34,
# ...

# %%
# Get a random image path
image_id = random.sample(os.listdir(base_path / "train"), 1)
# Read the image
image = tf.io.read_file(str(base_path / "train" / image_id[0]))
image = tf.image.decode_jpeg(image, channels=3)
# Make a list with the masks that image_id match
image_masks = ground_truth_df.loc[ground_truth_df["ImageId"] == str(image_id[0]), "EncodedPixels"].tolist()
# Take the individual ship masks and create a single mask array for all ships
# Set tensor with zeros value for all masks; (768, 768) - it's shape of ground truth masks
all_masks = tf.zeros((768, 768), dtype=tf.float32)
# Iter through rle strings of all masks for concrete image
if image_masks[0] is not np.nan:
    for mask in image_masks:
        # Add mask to only one tensor for all masks
        all_masks += tf.transpose(rle_decode(mask))

# Create plot with 3 different sight of image (with masks)
_, ax = plt.subplots(1, 3, figsize=(15, 40))
ax[0].axis("off")
ax[1].axis("off")
ax[2].axis("off")
ax[0].imshow(image)
ax[1].imshow(all_masks)
ax[2].imshow(image)
ax[2].imshow(all_masks, alpha=0.4)
plt.tight_layout(h_pad=0.1, w_pad=0.1)
plt.show()

# %%
# Define list ids
train_list_ids = os.listdir(base_path / "train")

# %%
# Splitting dataset on train & validation list with ids
train_list_ids, valid_list_ids = train_valid_ids_split(train_list_ids)
valid_list_ids, test_list_ids = train_valid_ids_split(valid_list_ids, train_split=0.5)

# %%
# Add hyperparameters for dataset
batch_size = 22
image_size = (128, 128)

# %%
# Initialize data generators for lists
train_data_gen = ASDGenerator(train_list_ids, ground_truth_df, batch_size=batch_size,
                              image_size=image_size, base_path=base_path / "train")
valid_data_gen = ASDGenerator(valid_list_ids, ground_truth_df, batch_size=batch_size,
                              image_size=image_size, base_path=base_path / "train")

# %% [markdown]
# ### Build Pipeline for Experiments

# %%
# Prepare table to collecting results of experiments
exp_results_df = pd.DataFrame({"model_id": [],
                               "entry_filters": [],
                               "entry_kernel_size": [],
                               "learning_rate": [],
                               "training_time": [],
                               "val_dice_loss": [],
                               "val_dice_score": []})

# %% [markdown]
# #### Prepare Hyperparameters set

# %%
# Initialize class DiceScore & Dice loss for evaluate model performance
dice_score = DiceScore()
dice_loss = DiceLoss()

# %%
# Initialize optimizer
learning_rates = (1e-4, 1e-3)
optimizer = Adam

# %%
# Initialize model architecture hyperparameters
entry_filters_size = (32, 64)
entry_kernel_size = (3, 4)
entry_activation = "relu"

# %%
# Initialize training hyperparameters
epochs = 7

# %% [markdown]
# #### Prepare pipeline function to process experiments

# %%
def exp_pipeline(image_size, train_ds, valid_ds, loss_fun, metrics, optimizer, learning_rate,
                 entry_filters, entry_kernel_size, entry_activation, experiment_df, model_ids):
    """"""

    # Define variable time for calculate time of training process
    start = time.time()

    # Define model weights paths to saving weight of the trained model
    model_weights_path = f"../models/asd_model/model/weights/asd_model_weights_lr{learning_rate}_filt{entry_filters}_kr{entry_kernel_size}/asd_weights"
    model_save_path = f"../models/asd_model/model/asd_model_lr{learning_rate}_filt{entry_filters}_kr{entry_kernel_size}/asd_model.h5"
    model_checkpoint_path = f"../models/asd_model/checkpoint/cp_lr{learning_rate}_filt{entry_filters}_kr{entry_kernel_size}/cp.ckpt"

    asd_model = get_model(image_size, 1, entry_filters, entry_kernel_size, entry_activation)

    asd_model.compile(loss=loss_fun,
                      optimizer=optimizer(learning_rate=learning_rate),
                      weighted_metrics=metrics)

    # Define callbacks to save model checkpoint weights
    callbacks = [
        ModelCheckpoint(model_checkpoint_path,
                        monitor="val_loss",
                        save_weights_only=True,
                        save_best_only=True,
                        verbose=0)
    ]

    # == Fit model ==
    model_history = asd_model.fit(train_ds,
                              steps_per_epoch=len(train_ds),
                              epochs=epochs,
                              validation_data=valid_ds,
                              validation_steps=len(valid_ds),
                              callbacks=callbacks)

    training_time = time.time() - start
    print("Model with --- filters:{} kernel size:{} learning rate:{} ---".format(entry_filters,
                                                                          entry_kernel_size,
                                                                          learning_rate))
    print("=== Training duration is %s second ===" % training_time)
    experiment_df.loc[len(experiment_df)] = [f"model_{next(model_ids)}",
                                             entry_filters,
                                             entry_kernel_size,
                                             learning_rate,
                                             training_time,
                                             '',
                                             '']

    # Plotting history of model training curves
    plot_history_curves(model_history)

    asd_model.save_weights(model_weights_path)
    asd_model.save(model_save_path)

# %% [markdown]
# ### Taking experiments with model

# %%
model_ids = itertools.count()
for filters, kernel, lr_rate in itertools.product(entry_filters_size, entry_kernel_size,
                                                          learning_rates):
    exp_pipeline(image_size, train_data_gen, valid_data_gen, dice_loss, [dice_score],
                 optimizer, lr_rate, filters, kernel, entry_activation, exp_results_df, model_ids)
# Out:
# Epoch 1/7
# 318/318 [==============================] - 253s 771ms/step - loss: 0.8181 - dice_score: 0.5653 - val_loss: 0.9995 - val_dice_score: 0.4997
# Epoch 2/7
# 318/318 [==============================] - 173s 545ms/step - loss: 0.7113 - dice_score: 0.6265 - val_loss: 0.8371 - val_dice_score: 0.5030
# Epoch 3/7
# 318/318 [==============================] - 175s 549ms/step - loss: 0.6395 - dice_score: 0.6155 - val_loss: 0.6641 - val_dice_score: 0.5798
# Epoch 4/7
# 318/318 [==============================] - 174s 547ms/step - loss: 0.5882 - dice_score: 0.6247 - val_loss: 0.6483 - val_dice_score: 0.5633
# Epoch 5/7
# 318/318 [==============================] - 171s 539ms/step - loss: 0.5407 - dice_score: 0.6183 - val_loss: 0.6454 - val_dice_score: 0.5536
# Epoch 6/7
# 318/318 [==============================] - 171s 538ms/step - loss: 0.4972 - dice_score: 0.5934 - val_loss: 0.5945 - val_dice_score: 0.5669
# Epoch 7/7
# ...

# %%
# Save table of experiments result
exp_results_df.to_csv("../output/experiments_result.csv")

# %% [markdown]
# ### Evaluate model

# %%
# Read table of experiments result
exp_results_df = pd.read_csv("../output/experiments_result.csv")
exp_results_df = exp_results_df.drop(columns=["Unnamed: 0"])

# %%
# Define test set of the dataset
test_data_gen = ASDGenerator(test_list_ids, ground_truth_df, batch_size=batch_size,
                              image_size=image_size, base_path=base_path / "train")

# %%
def evaluate_model(filters, kernel_size, lr_rate):
    """
    To evaluate all models and write all results to table.
    :param lr_rate: learning rate for optimizer;
    :param filters: number of filter for entry convolution;
    :param kernel_size: kernel size of entry convolution;
    """
    model_weights_path = f"../models/asd_model/model/weights/asd_model_weights_lr{lr_rate}_filt{filters}_kr{kernel_size}/asd_weights"
    # model_save_path = f"../models/asd_model/model/asd_model_lr{1e-3}_filt{32}_kr{3}/asd_model.h5"

    # Define & load model (or its weights)
    # asd_loaded_model = load_model(model_save_path, custom_objects={"loss": DiceLoss})
    asd_loaded_model = get_model(image_size, 1, filters, kernel_size, "relu")
    asd_loaded_model.load_weights(model_weights_path)

    # Compile model (if loaded weights, not for entire loaded model)
    asd_loaded_model.compile(loss=dice_loss,
                             optimizer=Adam(learning_rate=lr_rate),
                             metrics=[dice_score])

    loss, score = asd_loaded_model.evaluate(test_data_gen)

    score = np.mean(score)
    model_id = next(model_ids)

    exp_results_df.at[model_id, "val_dice_loss"] = loss
    exp_results_df.at[model_id, "val_dice_score"] = score

    print("Model: model_{}, filter: {}, kernel size: {}, learning rate: {}".format(model_id, filters, kernel_size, lr_rate))
    print("dice loss: {:.4f}, dice score: {:.4f}".format(loss, score))
    print()

# %%
model_ids = itertools.count()
for filters, kernel, lr_rate in itertools.product(entry_filters_size, entry_kernel_size,
                                                          learning_rates):
    evaluate_model(filters, kernel, lr_rate)
# Out:
# 31/31 [==============================] - 13s 413ms/step - loss: 0.4755 - dice_score: 0.5422
# Model: model_0, filter: 32, kernel size: 3, learning rate: 0.0001
# dice loss: 0.4755, dice score: 0.5422
#
# 31/31 [==============================] - 13s 411ms/step - loss: 1.0000 - dice_score: 0.5404
# Model: model_1, filter: 32, kernel size: 3, learning rate: 0.001
# dice loss: 1.0000, dice score: 0.5404
#
# 31/31 [==============================] - 13s 411ms/step - loss: 0.4819 - dice_score: 0.5411
# Model: model_2, filter: 32, kernel size: 4, learning rate: 0.0001
# dice loss: 0.4819, dice score: 0.5411
#
# 31/31 [==============================] - 13s 411ms/step - loss: 1.0000 - dice_score: 0.5395
# Model: model_3, filter: 32, kernel size: 4, learning rate: 0.001
# dice loss: 1.0000, dice score: 0.5395
#
# ...

# %%
# Save results to csv
exp_results_df.to_csv("../output/experiments_result.csv")

# %%
# View on best model
exp_results_df
# Out:
#                model_id  entry_filters  entry_kernel_size  learning_rate
# 0               model_0           32.0                3.0         0.0001  \
# 1               model_1           32.0                3.0         0.0010
# 2               model_2           32.0                4.0         0.0001
# 3               model_3           32.0                4.0         0.0010
# 4               model_4           64.0                3.0         0.0001
# 5               model_5           64.0                3.0         0.0010
# 6               model_6           64.0                4.0         0.0001
# 7               model_7           64.0                4.0         0.0010
# model_0             NaN            NaN                NaN            NaN
# model_count(1)      NaN            NaN                NaN            NaN
# count(0)            NaN            NaN                NaN            NaN
# 0                   NaN            NaN                NaN            NaN
#
# ...

# %%
# Load model with best dice loss
model_weights_path = f"../models/asd_model/model/weights/asd_model_weights_lr{1e-4}_filt{32}_kr{3}/asd_weights"
# model_save_path = f"../models/asd_model/model/asd_model_lr{1e-3}_filt{32}_kr{3}/asd_model.h5"

# Define & load model (or its weights)
# asd_loaded_model = load_model(model_save_path, custom_objects={"loss": DiceLoss})
asd_loaded_model = get_model(image_size, 1, 32, 3, "relu")
asd_loaded_model.load_weights(model_weights_path)

# Compile model (if loaded weights, not for entire loaded model)
asd_loaded_model.compile(loss=dice_loss,
                         optimizer=Adam(learning_rate=1e-4),
                         metrics=[dice_score])

# %%
# Define another test list ids (in folder test, and without masks)
test_list_ids = os.listdir(base_path / "test")

# %%
# Load image for testing
test_image = load_prepare_image(str(base_path / "test" / test_list_ids[35]), image_size)

# %%
pred_mask = asd_loaded_model.predict(test_data_gen[20][0])
# Out:
# 1/1 [==============================] - 0s 414ms/step

# %%
asd_loaded_model.evaluate(test_data_gen)
# Out:
# 31/31 [==============================] - 14s 412ms/step - loss: 0.4755 - dice_score: 0.5349
# [0.47549116611480713, array([0.9994287 , 0.07037739], dtype=float32)]

# %%
image_num = 14

# %%
# Show true image and mask predicted by our model (pred mask with alpha=0.4 value)
_, axis = plt.subplots(1, 3, figsize=(14, 8))
# Display true image
axis[0].axis("off")
axis[0].imshow(test_data_gen[20][0][image_num])
# Display predicted mask
axis[1].axis("off")
axis[1].imshow(pred_mask[image_num])
# Display true image with predicted mask with alpha=0.4
axis[2].axis("off")
axis[2].imshow(test_data_gen[20][0][image_num])
axis[2].imshow(pred_mask[image_num], alpha=0.4)
plt.tight_layout(h_pad=0.1, w_pad=0.1)
plt.show()
